# %% [markdown]
# # data.ca.gov
#
# The Employment Development Department of the Staet of California offers a [CKAN](https://docs.ckan.org/en/latest/user-guide.html#what-is-ckan) data [API](https://data.ca.gov/api/1/util/snippet/api_info.html?resource_id=5642307f-30c2-4ddb-b811-507b338e0b4d) that can be queried using SQL (*likely SQLite*).

# %%
# Dependencies:

# !pip install fuzzywuzzy
# !pip install urllib3

# %%
import pandas as pd
import requests

# %%
def clean_sql(sql: str) -> str:
    """ 
    Helper function to clean SQL queries for requests to the CA Open Data Portal
    """
    return " ".join(sql.replace("\n", " ").split())

# %%
# Source: https://data.ca.gov/organization/california-employment-development-department
ca_labor_market_data = {
    "occupation": "274e273c-d18c-4d84-b8df-49b4d13c14ce",
    "industry": "5642307f-30c2-4ddb-b811-507b338e0b4d",
}

sql_url = "https://data.ca.gov/api/3/action/datastore_search_sql"

# %% [markdown]
# ---

# %% [markdown]
# ## Gathering the Data Element Dictionaries
#
# The function below gathers the data element dictionaries from the CA Open Data Portal. These define the columns of the data sets.

# %%
def get_data_dictionary(data_type: str) -> pd.DataFrame:
    """
    Get the data dictionary for the specified data type from the CA Open Data
    Portal

    :param data_type: Either "occupation" or "industry"
    :return: A DataFrame containing the data dictionary
    """
    base_url = "https://data.ca.gov/dataset/"
    if data_type == "occupation":
        base_url += "long-term-occupational-employment-projections/resource/"
    elif data_type == "industry":
        base_url += "long-term-industry-employment-projections/resource/"
    else:
        raise ValueError(
            "Invalid data type. Must be either 'occupation' or 'industry'."
        )
    resource_id = ca_labor_market_data[data_type]
    url = f"{base_url}{resource_id}"
    return pd.read_html(url)[0] # [1] gives data recency information

# %%
get_data_dictionary("occupation")
# Out:
#                                         Column     Type  \
# 0                                    Area Type     text
# 1                                    Area Name     text
# 2                                       Period     text
# 3                                    SOC Level  numeric
# 4   Standard Occupational Classification (SOC)     text
# 5                           Occupational Title     text
# 6                Base Year Employment Estimate  numeric
# 7           Projected Year Employment Estimate  numeric
# 8                               Numeric Change  numeric
# 9                            Percentage Change  numeric
# 10                                       Exits  numeric
# 11                                   Transfers  numeric
# 12                          Total Job Openings  numeric
# 13                          Median Hourly Wage  numeric
# 14                          Median Annual Wage  numeric
# 15                       Entry Level Education     text
# 16                             Work Experience     text
# 17                                Job Training     text
#
#                                        Label  \
# 0                                  area_type
# 1                                  area_name
# 2                                     period
# 3                                  soc_level
# 4   standard_occupational_classification_soc
# 5                         occupational_title
# 6              base_year_employment_estimate
# 7         projected_year_employment_estimate
# 8                             numeric_change
# 9                          percentage_change
# 10                                     exits
# 11                                 transfers
# 12                        total_job_openings
# 13                        median_hourly_wage
# 14                        median_annual_wage
# 15                     entry_level_education
# 16                           work_experience
# 17                              job_training
#
#                                           Description
# 0   The type of geographic area (e.g., State, Coun...
# 1           The official name of the geographic area.
# 2   The 4-digit calendar years of the base and pro...
# 3       The level of detail of the occupational code.
# 4   The classification of workers into occupationa...
# 5                       The official occupation name.
# 6                The number of jobs in the base year.
# 7           The number of jobs in the projected year.
# 8   Difference in employment between base and proj...
# 9     Numeric change divided by base year employment.
# 10  The projected number of workers leaving an occ...
# 11  The projected number of workers leaving an occ...
# 12  The projected number of openings (positions) f...
# 13  The median hourly wage for an occupation, in 2...
# 14  The median annual wage for an occupation, in 2...
# 15  The typical education level most workers need ...
# 16  The typical work experience in a related occup...
# 17  The typical on-the-job training needed to atta...

# %%
get_data_dictionary("industry")
# Out:
#                                Column     Type  \
# 0                           Area Type     text
# 1                           Area Name     text
# 2                              Period     text
# 3                         Series Code     text
# 4                      Industry Title     text
# 5       Base Year Employment Estimate  numeric
# 6  Projected Year Employment Estimate  numeric
# 7                      Numeric Change  numeric
# 8                   Percentage Change  numeric
#
#                                 Label  \
# 0                           area_type
# 1                           area_name
# 2                              period
# 3                         series_code
# 4                      industry_title
# 5       base_year_employment_estimate
# 6  projected_year_employment_estimate
# 7                      numeric_change
# 8                   percentage_change
#
#                                          Description
# 0  The type of geographic area (e.g., State, Coun...
# 1          The official name of the geographic area.
# 2  The 4-digit calendar years of the base and pro...
# 3          The code identifying the specific series.
# 4                        The official industry name.
# 5               The number of jobs in the base year.
# 6          The number of jobs in the projected year.
# 7  Difference in employment between base and proj...
# 8    Numeric change divided by base year employment.

# %% [markdown]
# ---

# %% [markdown]
# ## Querying the Database

# %%
def labor_market_sql_to_dataframe(sql: str) -> pd.DataFrame:
    """
    Executes a SQL query against the CA Open Data Portal and converts the 
    result set to a DataFrame

    :param sql: The SQL query to execute
    :return: A DataFrame containing the results of the query
    """
    try:
        response = requests.get(sql_url, params={"sql": clean_sql(sql)})
        response.raise_for_status()
    except requests.exceptions.HTTPError as e:
        print(f"Error raised with SQL:\n{sql}\nError message: {e}")
        return pd.DataFrame()

    data = response.json()
    return pd.DataFrame(data.get("result", {}).get("records", {}))

# %%
sql = f""" 
    SELECT
        "Occupational Title",
        ROUND(AVG("Numeric Change"), 2) AS "Average Projected Employment Change"
    FROM
        "{ca_labor_market_data['occupation']}"
    WHERE
        "SOC Level" = 2
        AND "Area Name" <> 'California'
    GROUP BY
        "Occupational Title"
    ORDER BY
        "Average Projected Employment Change" DESC
"""

# %%
df = labor_market_sql_to_dataframe(sql)
df.head()
# Out:
#                                  Occupational Title  \
# 0  Food Preparation and Serving Related Occupations
# 1    Transportation and Material Moving Occupations
# 2                    Healthcare Support Occupations
# 3                            Management Occupations
# 4     Business and Financial Operations Occupations
#
#   Average Projected Employment Change
# 0                            14808.75
# 1                             9894.06
# 2                             8740.63
# 3                             7585.00
# 4                             5667.81

# %%
sql = f""" 
    SELECT DISTINCT
        "Occupational Title"
    FROM
        "{ca_labor_market_data['occupation']}"
    WHERE
        /* Test of comment */
        "SOC Level" = 4
"""

# %%
df = labor_market_sql_to_dataframe(sql)
df.head()
# Out:
#                                   Occupational Title
# 0  Passenger Vehicle Drivers, Except Bus Drivers,...
# 1                           Food Preparation Workers
# 2                                 Rail Car Repairers
# 3  Farmers, Ranchers, and Other Agricultural Mana...
# 4  Woodworking Machine Setters, Operators, and Te...

# %%
sql = f""" 
    SELECT DISTINCT
        *
    FROM
        "{ca_labor_market_data['occupation']}"
    WHERE
        "SOC Level" = 3
"""

# %%
df = labor_market_sql_to_dataframe(sql)
df.sample(10)
# Out:
#         _id                                         _full_text  \
# 222    1631  '-2032':4 '-9000':7 '0':20 '0.00':19 '11.5':15...
# 2045  11969  '-2030':20 '-9000':23 '0':38 '0.00':37 '10080'...
# 2877  16469  '-2030':10 '-5000':13 '0':29 '0.00':28 '1240':...
# 2506  14499  '-2030':13 '-9000':16 '0':30 '0.00':29 '1330':...
# 891    5247  '-1000':11 '-2030':8 '0':27 '0.00':26 '11.8':2...
# 2076  12149  '-2030':20 '-8000':23 '0':36 '0.00':35 '1030':...
# 1365   7628  '-1000':17 '-2030':14 '0':28 '0.00':27 '15970'...
# 2212  13034  '-10':29 '-2.4':30 '-2000':21 '-2030':18 '0':3...
# 2425  14058  '-2030':12 '-4000':15 '0':29 '0.00':28 '10':23...
# 2380  13844  '-2030':12 '-3000':15 '0':28 '0.00':27 '1000':...
#
#               Area Type                                          Area Name  \
# 222               State                                         California
# 2045  Metropolitan Area  San Francisco-Redwood City-South San Francisco...
# 2877  Metropolitan Area            Visalia-Porterville MSA (Tulare County)
# 2506  Metropolitan Area  Santa Maria-Santa Barbara MSA (Santa Barbara C...
# 891   Metropolitan Area                         Madera MSA (Madera County)
# 2076  Metropolitan Area  San Francisco-Redwood City-South San Francisco...
# 1365  Metropolitan Area  Oakland-Hayward-Berkeley MD (Alameda and Contr...
# 2212  Metropolitan Area  San Luis Obispo-Paso Robles-Arroyo Grande MSA ...
# 2425  Metropolitan Area     Santa Cruz-Watsonville MSA (Santa Cruz County)
# 2380  Metropolitan Area     Santa Cruz-Watsonville MSA (Santa Cruz County)
#
#          Period SOC Level Standard Occupational Classification (SOC)  \
# 222   2022-2032         3                                    33-9000
# 2045  2020-2030         3                                    39-9000
# 2877  2020-2030         3                                    43-5000
# 2506  2020-2030         3                                    41-9000
# 891   2020-2030         3                                    53-1000
# 2076  2020-2030         3                                    51-8000
# 1365  2020-2030         3                                    25-1000
# 2212  2020-2030         3                                    33-2000
# 2425  2020-2030         3                                    45-4000
# 2380  2020-2030         3                                    25-3000
#
#                                      Occupational Title  \
# 222                    Other Protective Service Workers
# 2045            Other Personal Care and Service Workers
# 2877  Material Recording, Scheduling, Dispatching, a...
# 2506                    Other Sales and Related Workers
# 891   Supervisors of Transportation and Material Mov...
# 2076                         Plant and System Operators
# 1365                             Postsecondary Teachers
# 2212               Fire Fighting and Prevention Workers
# 2425          Forest, Conservation, and Logging Workers
# 2380                     Other Teachers and Instructors
#
#      Base Year Employment Estimate Projected Year Employment Estimate  \
# 222                         250100                             278800
# 2045                         10460                              13230
# 2877                          2140                               2350
# 2506                          1330                               1550
# 891                            170                                190
# 2076                          1030                               1070
# 1365                         16000                              16920
# 2212                           420                                410
# 2425                            70                                 80
# 2380                          1700                               2040
#
#      Numeric Change Percentage Change   Exits Transfers Total Job Openings  \
# 222           28700              11.5  208140    218190             455030
# 2045           2770              26.5    7200     10080              20050
# 2877            210               9.8     820      1240               2270
# 2506            220              16.5     860       890               1970
# 891              20              11.8      70       130                220
# 2076             40               3.9     410       720               1170
# 1365            920               5.8    7360      7690              15970
# 2212            -10              -2.4     100       210                300
# 2425             10              14.3      30        90                130
# 2380            340              20.0    1110      1000               2450
#
#      Median Hourly Wage Median Annual Wage Entry Level Education  \
# 222                0.00                  0                   N/A
# 2045               0.00                  0                   N/A
# 2877               0.00                  0                   N/A
# 2506               0.00                  0                   N/A
# 891                0.00                  0                   N/A
# 2076               0.00                  0                   N/A
# 1365               0.00                  0                   N/A
# 2212               0.00                  0                   N/A
# 2425               0.00                  0                   N/A
# 2380               0.00                  0                   N/A
#
#      Work Experience Job Training
# 222              N/A          N/A
# 2045             N/A          N/A
# 2877             N/A          N/A
# 2506             N/A          N/A
# 891              N/A          N/A
# 2076             N/A          N/A
# 1365             N/A          N/A
# 2212             N/A          N/A
# 2425             N/A          N/A
# 2380             N/A          N/A

# %% [markdown]
# ---

# %% [markdown]
# ## Integration with CCC API

# %% [markdown]
# ### CA Data

# %%
sql = f"""
    SELECT DISTINCT
        "Area Name"
    FROM 
        "{ca_labor_market_data['occupation']}"
"""

# %%
areas = labor_market_sql_to_dataframe(sql)
areas.head()
# Out:
#                                            Area Name
# 0                        Redding MSA (Shasta County)
# 1  Oakland-Hayward-Berkeley MD (Alameda and Contr...
# 2                         Fresno MSA (Fresno County)
# 3  San Jose-Sunnyvale-Santa Clara MSA (San Benito...
# 4  Riverside-San Bernardino-Ontario MSA (Riversid...

# %%
# Split the "Area Name" column at the parentheses
areas[['Metropolitan Statistical Areas', 'Counties']] = (
    areas['Area Name'].str.extract(r'^(.*) \((.*)\)$')
)

areas.head()
# Out:
#                                            Area Name  \
# 0                        Redding MSA (Shasta County)
# 1  Oakland-Hayward-Berkeley MD (Alameda and Contr...
# 2                         Fresno MSA (Fresno County)
# 3  San Jose-Sunnyvale-Santa Clara MSA (San Benito...
# 4  Riverside-San Bernardino-Ontario MSA (Riversid...
#
#          Metropolitan Statistical Areas                               Counties
# 0                           Redding MSA                          Shasta County
# 1           Oakland-Hayward-Berkeley MD      Alameda and Contra Costa Counties
# 2                            Fresno MSA                          Fresno County
# 3    San Jose-Sunnyvale-Santa Clara MSA    San Benito and Santa Clara Counties
# 4  Riverside-San Bernardino-Ontario MSA  Riverside and San Bernardino Counties

# %% [markdown]
# ### CCC Data

# %%
# Requests to https://api.cccco.edu/ always throw SSL warnings. 
# Suppress them here.

import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
def get_colleges(search_param: str | None = None) -> pd.DataFrame:
    """
    Sends a `GET` request to the CCCCO API to retrieve a list of colleges.

    :param search_param: The parameters for the search query. Either the college
        MIS ID or the college name. If `None`, all colleges are returned.
    :return: A pandas DataFrame containing the list of colleges.
    """

    cccco_api_url = "https://api.cccco.edu/"

    if not search_param:
        cccco_api_url += "colleges"
    elif search_param.isnumeric():
        cccco_api_url += f"colleges/{search_param}"
    else:
        cccco_api_url += f"colleges/search/{search_param}"

    response = requests.get(cccco_api_url, verify=False)
    response.raise_for_status()
    return pd.DataFrame(response.json()).drop(columns=["CollegeContacts"])

# %%
colleges = get_colleges()

# %% [markdown]
# We'll need to (fuzzy) join the labor market data with the CCC data on the County fields.

# %%
from fuzzywuzzy import process


def get_best_match(county: str, choices: list[str]) -> str | None:
    """ 
    Uses fuzzy matching to find the best match for a given county in a list of 
    choices.

    :param county: The county to match.
    :param choices: The list of choices to match against.
    :return: The best match for the county in the list of choices.
    """
    best_match = process.extractOne(county, choices)
    return best_match[0] if best_match else None
# Out:
# c:\Users\codyc\anaconda3\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
area_counties = areas["Counties"].dropna().unique()

colleges["Matched Counties"] = colleges["County"].apply(
    lambda x: get_best_match(x, area_counties)
)

merged_df = pd.merge(
    colleges, areas, left_on="Matched Counties", right_on="Counties", how="left"
)

merged_df.head()
# Out:
#   CollegeID              CollegeName DistrictID                 StreetAddress  \
# 0       021         Cuyamaca College        020  900 Rancho San Diego Parkway
# 1       022        Grossmont College        020  8800 Grossmont College Drive
# 2       031  Imperial Valley College        030            380 East Aten Road
# 3       051        MiraCosta College        050               1 Barnard Drive
# 4       061          Palomar College        060        1140 West Mission Road
#
#          City      County    Zip ZipPlus4                 MailingAddress  \
# 0    El Cajon  San Diego   92019     4304   900 Rancho San Diego Parkway
# 1    El Cajon  San Diego   92020     1799  8800 Grossmont College Drive
# 2    Imperial   Imperial   92251     9787            380 East Aten Road
# 3   Oceanside  San Diego   92056     3899               1 Barnard Drive
# 4  San Marcos  San Diego   92069     1487        1140 West Mission Road
#
#   MailingCity  ...          Phone         WebsiteURL   Latitude   Longitude  \
# 0    El Cajon  ...  619.660.4000    www.cuyamaca.edu  32.744890 -116.935229
# 1    El Cajon  ...  619.644.7000   www.grossmont.edu  32.817897 -117.005640
# 2    Imperial  ...  760.352.8320    www.imperial.edu  32.825859 -115.502999
# 3   Oceanside  ...  760.757.2121   www.miracosta.edu  33.188864 -117.301064
# 4  San Marcos  ...  760.744.1150     www.palomar.edu  33.147015 -117.183980
#
#                              LogoURL District  Matched Counties  \
# 0            CuyamacaCollegeLogo.jpg     None  San Diego County
# 1           GrossmontCollegelogo.jpg     None  San Diego County
# 2  ImperialValleyCollegeLogocopy.jpg     None   Imperial County
# 3     Mira_Costa_College_Logo_4c.png     None  San Diego County
# 4             PalomarCollegeLogo.jpg     None  San Diego County
#
#                                    Area Name Metropolitan Statistical Areas  \
# 0  San Diego-Carlsbad MSA (San Diego County)         San Diego-Carlsbad MSA
# 1  San Diego-Carlsbad MSA (San Diego County)         San Diego-Carlsbad MSA
# 2            El Centro MSA (Imperial County)                  El Centro MSA
# 3  San Diego-Carlsbad MSA (San Diego County)         San Diego-Carlsbad MSA
# 4  San Diego-Carlsbad MSA (San Diego County)         San Diego-Carlsbad MSA
#
#            Counties
# 0  San Diego County
# 1  San Diego County
# 2   Imperial County
# 3  San Diego County
# 4  San Diego County
#
# [5 rows x 21 columns]

# %%
merged_df[
    [
        "CollegeID",
        "CollegeName",
        "County",
        "Matched Counties",
        "Area Name",
        "Metropolitan Statistical Areas",
    ]
].sample(10) # Merge was successful
# Out:
#     CollegeID                    CollegeName           County  \
# 65        592         Modesto Junior College      Stanislaus
# 63        582                Lemoore College           Kings
# 78        741       Los Angeles City College     Los Angeles
# 55        531                 Merced College          Merced
# 32        343                  Laney College          Alameda
# 99        873        Santiago Canyon College   Orange County
# 113       982  San Bernardino Valley College  San Bernardino
# 90        821                 Citrus College     Los Angeles
# 52        521            Bakersfield College     Kern County
# 74        691                   Taft College     Kern County
#
#                           Matched Counties  \
# 65                       Stanislaus County
# 63                            Kings County
# 78                      Los Angeles County
# 55                           Merced County
# 32       Alameda and Contra Costa Counties
# 99                           Orange County
# 113  Riverside and San Bernardino Counties
# 90                      Los Angeles County
# 52                             Kern County
# 74                             Kern County
#
#                                              Area Name  \
# 65                     Modesto MSA (Stanislaus County)
# 63                 Hanford-Corcoran MSA (Kings County)
# 78   Los Angeles-Long Beach-Glendale MD (Los Angele...
# 55                          Merced MSA (Merced County)
# 32   Oakland-Hayward-Berkeley MD (Alameda and Contr...
# 99         Anaheim-Santa Ana-Irvine MD (Orange County)
# 113  Riverside-San Bernardino-Ontario MSA (Riversid...
# 90   Los Angeles-Long Beach-Glendale MD (Los Angele...
# 52                       Bakersfield MSA (Kern County)
# 74                       Bakersfield MSA (Kern County)
#
#            Metropolitan Statistical Areas
# 65                            Modesto MSA
# 63                   Hanford-Corcoran MSA
# 78     Los Angeles-Long Beach-Glendale MD
# 55                             Merced MSA
# 32            Oakland-Hayward-Berkeley MD
# 99            Anaheim-Santa Ana-Irvine MD
# 113  Riverside-San Bernardino-Ontario MSA
# 90     Los Angeles-Long Beach-Glendale MD
# 52                        Bakersfield MSA
# 74                        Bakersfield MSA

# %% [markdown]
# ---
